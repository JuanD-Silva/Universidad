# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanD-Silva/Universidad/blob/main/IA/Primer_Corte_Megaquilidos_Robot_Aspiradora_Megaquilidos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # __Laboratorio 1. Agentes Inteligentes__
#
#
# El siguiente laboratorio está relacionado con el proceso de solución de problemas en IA utilizando el concepto de agente. Para el desarrollo del laboratorio tenga en cuenta lo siguiente:
#
# * La actividad puede realizarse en grupos de máximo 3 personas
# * La solución del laboratorio debe enviarse en un notebook a través de Moodle. Se debe adjuntar el archivo. No se aceptan enlaces.
# * El uso del lenguaje matemático debe hacerse utilizando `LaTeX`
# * El objetivo del laboratorio es hacer énfasis en el proceso de modelamiento. Sea claro en sus respuestas
# * Si se detecta cualquier tipo de fraude, la calificación de 0.0.
# * El código implementado deben cumplir con las recomendaciones de código limpio especificadas en el [PEP8](https://pep8.org/), de lo contrario será penalizado
# _______________________________________

# %% [markdown]
# ###__Megaquilidos__
#
# ###### Juan David Silva, Sebastian Urrego y Daniel Steven Reyes

# %% [markdown]
# ####  __1. `(0.5 puntos)` Suponga que un agente selecciona su siguiente movimiento de manera aleatoria del conjunto de acciones posibles. Si todas las acciones tiene la misma probabilidad, ¿existe un problema en específico dónde el agente tenga un comportamiento racional? Justifique su respuesta.__

# %%
# Solución propuesta

# %% [markdown]
# No, pues desde un principio se indica que el agente selecciona su movimiento de manera aleatoria, que tienen la misma probabilidad de ejecutarlas y la aleatoriedad no es un comportamineto racional.
#
# A no ser de que el agente tenga un objetivo y sea un agente de aprendisaje que con base a historial de moviminetos mejore sus deciciones recionalmente para mejorar su utilidad y alcanzar el objetivo propuesto.

# %% [markdown]
# #### __2. `(0.5 puntos)` Suponga que el comportamiento de un agente es evaluado a través de una métrica de desempeño que solo considera las primeras 𝑇 unidades de tiempo e ignora todo lo demás después de eso. Muestre que la racionalidad del agente no depende únicamente del estado del ambiente, sino del tiempo disponible. Presente 2 ejemplos para esta situación.__

# %%
# Solución propuesta

# %% [markdown]
# ##1. Un agente que hace inversiones en la bolsa de valores
# Un agente que hace inversiones en la bolsa de valores, que tiene en cuenta estartegias para evaluar el *T*, digamos si el *T* es grande(inversion a largo plazo) el agente se enfocara en empresas con fundamentos solidos, crecimiento estable y invertir en acciones de bajo riesgo con alta capitalización de mercado, por otro lado, si el *T* es corto(inversion a corto plazo) lo mas probable es que haga estrategias arriesgadas para aumentar ganancias en el menor tiempo posible.
#
# ##2.Agente de entrenamiento de un plito NASCARD
# Un agente que ayuda a un piloto de carreras de nascar, que tiene en cuenta los últimos tiempos (en minutos) que se demora dar una vuelta, este agente con base
# al tiempo y la velocidad en cada segmento de la pista le hace recomendaciones al piloto cada tres vueltas. También analiza el estado del vehiculo para decirle al piloto cuando debe entrar al pits para no afectar su performance.

# %% [markdown]
# #### __3. `(1.0 puntos)` Para cada uno de los siguientes problemas, especifique los elementos PEAS.  No olvide mencionar todas las propiedades del ambiente.__
#
# *	Jugar baloncesto
# *	Explorar la superficie de la luna
# *	Comprar una obra de arte en una subasta
# *	Jugar poker
# *	ChatBot para una mesa de ayuda.
# * Jugar Ajedrez

# %%
# Solución propuesta

# %% [markdown]
# ####Elementos PEAS Por cada actividad
#
#
# 1.   **Jugar baloncesto**
#
# *    **Performance:**
#
#   1.   Precision en tiros
#   2.   Capacidad defensiva
#   3.   Capacidad ofensiva
#   4.   Habilidad estrategica
#   5.   Resistencia
#   6.   Puntos hechos y asistencias dadas
#
# *   **Environment:**
#   1.   Cancha
#   2.   Gradas con publico
#   3.   Otros jugadores(tanto del mismo equipo como del equipo rival)
#   4.   Balon de baloncesto
#   5.   Aro y tablero
#
# *   **Actuators:**
#   1.   Brazos y manos(para lanzar la pelota, hacer pases a los compañeros de equipo, driblar jugadores rivales y bloquear tiros rivales)
#   2.   Comunicación (señales o voz para coordinar con los compañeros de equipo)
#   3.   Piernas y pies (para correr, saltar y moverse)
#
# *   **Sensors:**
#   1.   La vista(Ver a cual jugador se le va a hacer el pase, ver el posicionamiento de los rivales y ver la canasta al momento de encestar)
#   2.   El Sonido(para escuhar indicaciones de coach como de los compañeros de equipo)
#   3.    El tacto(Sentir el balon para hacer los pases y tiros correctamente)
#
# ######Tipos de Ambiente en jugar baloncesto🏀
# | Propiedad | Tipo |
# |----------|------------|
# | *Observable o Parcialmente Observable*   | Parcialmente Observable |
# | *Deterministico o estocastico*     |  Estocastico  |
# | *Estatico o Dinamico* | Dinamico |
# |*Discreto o Continuo*| Continuo|
# | *Episodico o Secuencial*   |  Secuencial   |
# | *Multi-Agente*     |    Si |
# | *Metrica de Desempeño conocida*     | puntos anotados y asistencias    |
#
# *   ****************************************************************************
# 2.   **Explorar la superficie de la luna**
# *    **Performance:**
#
#   1.   Duracion de la exploracion
#   2.   Resistencia a condiciones extremas
#   3.   Exploracion segura
#   4.   Recoleccion en muestras
#   5.   Buena comunicacion con los compañeros de exploracion
#
# *   **Environment:**
#   1.   Superficie rocosa con polvo lunar y crateres
#   2.   Gravedad reducida(1.62 m/s²)
#   3.   Obstaculos como rocas enormes y socabones grandes
#   4.   Falta de un atmosfera
#   5.   Temperaturas extremas
#   6.   Posible radiacion solar y espacial
#
# *   **Actuators:**
#   1.   Ruedas o patas robóticas para moverse en terreno irregular
#   2.   Antenas de comunicación para enviar datos a compañeros
#   3.   Sensores de ajuste de altitud y motores para estabilización
#   4.   Paneles solares para obtener energía
#
# *   **Sensors:**
#   1.   Sensores térmicos para monitorear temperatura
#   2.   Sensores de proximidad para evitar obstáculos
#   3.   Sensores de radiación para medir exposición al espacio
#   4.   Espectrómetros y analizadores de suelo para estudiar minerales
#
# ######Tipos de Ambiente en exploracion de la superficie de la luna🚀🌕
# | Propiedad | Tipo |
# |----------|------------|
# | *Observable o Parcialmente Observable*   | Parcialmente Observable |
# | *Deterministico o estocastico*     |  Estocastico  |
# | *Estatico o Dinamico* | Dinamico |
# |*Discreto o Continuo*| Continuo|
# | *Episodico o Secuencial*   |  Secuencial   |
# | *Multi-Agente*     |    No(pero se puede comunicar con compañeros de la exploracion) |
# | *Metrica de Desempeño conocida*     | Cantidad y calidad de datos recolectados, eficiencia energética, duración de la exploracion   |
#
# *   ****************************************************************************
#
# 3.   **Comprar una obra de arte en una subasta**
# *    **Performance:**
#
#   1.   Adquirir la obra de arte a un muy buen precio
#   2.   Evaluar si la obra es autentica
#   3.   Superar a lo demas postores sin pasarse en el presupuesto
#   4.   Saber cuando pujar y cuando retirar
#
# *   **Environment:**
#   1.   sala de la subasta
#   2.   Otros compradores
#   3.   Subastador que dirige el evento
#   4.   Obras de arte en subasta
#
# *   **Actuators:**
#   1.   Señas como levantar la mano cuando se va a proponer un precio de compra
#   2.   Comunicacion de manera verbal
#
# *   **Sensors:**
#   1.   Visión (para observar la obra y leer reacciones de los postores)
#   2.   Micrófono o sistema de audio (para escuchar las ofertas y reglas).
#   3.   Datos históricos de precios (para analizar el valor de la obra)
#
# ######Tipos de ambiente para comprar una obra de arte en una subasta🎨
# | Propiedad | Tipo |
# |----------|------------|
# | *Observable o Parcialmente Observable*   | Parcialmente Observable(puede no conocer la estrategia de los otros postores o el valor real de la obra) |
# | *Deterministico o estocastico*     |  Estocastico  |
# | *Estatico o Dinamico* | Dinamico |
# |*Discreto o Continuo*| Discreto |
# | *Episodico o Secuencial*   |  Secuencial   |
# | *Multi-Agente*     |  Sí (hay múltiples postores compitiendo por la obra) |
# | *Metrica de Desempeño conocida*     | Obra adquirida al mejor precio posible dentro del presupuesto |
#
# *   ****************************************************************************
#
# 4.   **Jugar póker**
#
# *    **Performance:**
#
#   1.   Maximizar las ganancias en fichas o dinero
#   2.   Minimizar pérdidas al retirarse en manos desfavorables
#   3.   Tomar buenas desiciones según las probabilidades
#   4.   Engañar a los oponentes
#
# *   **Environment:**
#   1.   Mesa de póker
#   2.   Cartas(tanto propias como comunitarias)
#   3.   Fichas y dinero en juego
#   4.   Rivales con estrategias
#
# *   **Actuators:**
#   1.   Realizar apuestas (subir, igualar o retirarse)
#   2.   Expresiones faciales o lenguaje corporal
#   3.   Control del tiempo para responder estratégicamente
#
# *   **Sensors:**
#   1.   Visión (para ver las cartas comunitarias y las fichas en juego)
#   2.   Análisis del comportamiento de los oponentes
#   3.   Información probabilística basada en las cartas visibles y posibles manos rivales
#
# ######Tipos de ambiente para jugar poker♠️♥️♣️♦️
# | Propiedad | Tipo |
# |----------|------------|
# | *Observable o Parcialmente Observable*   | Parcialmente Observable(no conoce las cartas ocultas de los oponentes) |
# | *Deterministico o estocastico*     |  Estocastico  |
# | *Estatico o Dinamico* | Dinamico(el estado del juego cambia con cada ronda de apuestas y nuevas cartas) |
# |*Discreto o Continuo*| Discreto |
# | *Episodico o Secuencial*   |  Secuencial   |
# | *Multi-Agente*     |  Si(interactúa con múltiples oponentes que pueden influir en sus decisiones) |
# | *Metrica de Desempeño conocida*     | Cantidad de fichas ganadas, éxito en faroles y rentabilidad a largo plazo |
#
# *   ****************************************************************************
#
# 5.   **ChatBot para una mesa de ayuda**
#
# *    **Performance:**
#
#   1.   Resolver dudas de usuarios de manera rapida y precisa
#   2.   Responder con respuestas claras
#   3.   Dar satisfaccion al usuario
#   4.   Mejorar continuamente con aprendizaje automático basado en interacciones
#   5.   Minimizar la necesidad de intervención humana
#
# *   **Environment:**
#   1.   Plataforma de chat (sitio web, app, WhatsApp, etc.)
#   2.   Usuarios con diferentes consultas
#   3.   Base de datos con información relevante para responder preguntas
#
# *   **Actuators:**
#   1.   Enviar mensajes de texto o voz con respuestas automáticas
#   2.   Proporcionar enlaces o documentos de soporte
#   3.   Transferir la conversación a un agente humano si es necesario
#   4.   Registrar y analizar interacciones para mejorar la asistencia
#
# *   **Sensors:**
#   1.   Procesamiento de lenguaje natural
#   2.   Historial de conversaciones (para personalizar respuestas)
#   3.   Base de datos de conocimientos (para encontrar respuestas correctas)
#
# ######Tipos de ambiente para un chatbot para una mesa de ayuda🤖💬
# | Propiedad | Tipo |
# |----------|------------|
# | *Observable o Parcialmente Observable*   | Parcialmente Observable (no siempre conoce el contexto completo del problema del usuario) |
# | *Deterministico o estocastico*     |  Estocastico  |
# | *Estatico o Dinamico* | Dinamico(el usuario puede hacer preguntas imprevistas o cambiar de tema) |
# |*Discreto o Continuo*| Discreto |
# | *Episodico o Secuencial*   |  Secuencial(cada respuesta influye en la siguiente interacción) |
# | *Multi-Agente*     |  Si(interactúa con múltiples usuarios y, en algunos casos, con agentes humanos) |
# | *Metrica de Desempeño conocida*     | Precisión en respuestas, tiempo de resolución, satisfacción del usuario |
#
# *   ****************************************************************************
#
# 6.   **Jugar Ajedrez**
#
# *    **Performance:**
#
#   1.   Ganar la partida
#   2.   Minimizar la pérdida de piezas valiosas
#   3.   Controlar el centro del tablero y mantener una posición favorable
#   4.   Predecir y responder a las jugadas del rival de manera eficiente
#   5.   Tener buen manejo del tiempo en la toma de decisiones
#
# *   **Environment:**
#   1.   Tablero de ajedrez de 8x8 casillas
#   2.   Piezas propias y del rival
#   3.   Turnos alternos entre los jugadores
#   4.   Posibles estrategias y tácticas del rival
#
# *   **Actuators:**
#   1.   Mover piezas en el tablero
#   2.   Realizar movimientos acorde a las reglas
#
# *   **Sensors:**
#   1.   Análisis de movimientos y patrones estratégicos
#   2.   Detección del estado del tablero(como posicionamiento de las piezas de uno como las del rival)
#   3.   Evaluación de la posición en términos de ventaja material y posicional
#
# ######Tipos de ambiente para jugar ajedrez♟️
# | Propiedad | Tipo |
# |----------|------------|
# | *Observable o Parcialmente Observable*   | Observable |
# | *Deterministico o estocastico*     |  Deterministico(las reglas y los movimientos son predecibles y no hay azar)  |
# | *Estatico o Dinamico* | Estático (el entorno no cambia hasta que el jugador hace un movimiento) |
# |*Discreto o Continuo*| Discreto |
# | *Episodico o Secuencial*   |  Secuencial(las jugadas influyen en la partida en curso)|
# | *Multi-Agente*     |  Si(Juega contra un rival) |
# | *Metrica de Desempeño conocida*     | Victoria en la partida, cantidad de piezas capturadas, control del tablero, eficiencia en los movimientos |

# %% [markdown]
# # __Robot Aspiradora__
#
# Los siguientes dos puntos utilizan el siguiente código como base.
#
# * Clase `Tablero`:
# * Clase `Agente`:
#
# Modifique las clases según lo considere necesario para cumplir los requerimientos de la simulación solicitada.

# %%
from IPython.display import display
import ipywidgets as widgets
import time

class Tablero:
  def __init__(self, tamano_celda=(50, 50), n_celdas=(5,5)):
    self.out = widgets.HTML()
    display(self.out)
    self.tamano_celda = tamano_celda
    self.n_celdas = n_celdas

  def dibujar(self, objetos):
    tablero = "<table border='1' >{}</table>"
    filas = ""

    for i in range(self.n_celdas[0]):
      s = ""
      for j in range(self.n_celdas[1]):
        contenido =""
        for o in objetos:
          if o.x == j and o.y == i:
            contenido = \
            "<div style='transform: rotate({angulo}deg);font-size:{tamano_emoticon}px;'>{emoticon}</div>".\
            format(angulo = o.angulo, tamano_emoticon = o.tamano_emoticon, emoticon = o.emoticon)
        s += "<td style='height:{alto}px;width:{ancho}px'>{contenido}</td>".\
          format(alto = self.tamano_celda[0], ancho = self.tamano_celda[1],
                contenido = contenido)
      filas += "<tr>{}</tr>".format(s)
    tablero = tablero.format(filas)
    self.out.value = tablero

# %%
class Agente:
  def __init__(self, x=0, y=0, angulo=0, emoticon="🤖", tamano_emoticon=30):
    self.x = x
    self.y = y
    self.angulo = angulo
    self.emoticon = emoticon
    self.tamano_emoticon = tamano_emoticon
    self.energia = 5

  def abajo(self):
    if self.y < 4 : self.y += 1

  def derecha(self):
    pass

  def arriba(self):
    pass

  def izquierda(self):
    pass

# %% [markdown]
# #### __4. `(1.5 puntos)` Implemente una simulación para el problema del robot aspiradora presentado en clase. La simulación debe cumplir las siguientes especificaciones:__
#
#   * El agente aspiradora puede percibir las hojas en cualquiera de las 4 casillas adyacentes (N, S, W, E).
#   * El agente puede percibir los muros del tablero
#   * El agente aspiradora dispondrá de 6 acciones:  moverse a cualquiera de las 4 casillas adyacentes (N, S, W, E), aspirar o no realizar ninguna acción.
#   * El agente obtendrá un punto por cada cuadrado que se limpie.
#   * La posición inicial de la aspiradora deberá generarse de manera aleatoria en el tablero.
#   * La aspiradora solo tiene energía para realizar 100 movimientos. Las acciones de aspirar y percibir las hojas no consumen energía.
#   * El tablero debe tener un tamaño de 5 x 5.
#   * Se deben ubicar 10 hojas de manera aleatoria en el tablero.
#
# __Utilizando los parámetros mencionados:__
#
#   * Genere un comportamiento reflejo que maximice el puntaje obtenido por la aspiradora. Describa la estrategia utilizada.
#   * Realice 50 simulaciones con el comportamiento diseñado y realice un histograma con los puntajes obtenidos.
#   * ¿Es posible construir un agente racional que soluciones este problema únicamente con comportamientos reflejos?

# %%
aspiradora = Agente()
tablero = Tablero(n_celdas=(5, 5))

basura1 = Agente(2, 2, 0, emoticon="🍂", tamano_emoticon=30)
basura2 = Agente(3, 3, 0, emoticon="🍂", tamano_emoticon=30)
basura3 = Agente(3, 2, 0, emoticon="🍂", tamano_emoticon=30)

objetos = [aspiradora, basura1, basura2, basura3]

for i in range(aspiradora.energia):
  tablero.dibujar(objetos)
  time.sleep(0.5)
  aspiradora.abajo()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-873e86c65b05> in <cell line: 0>()
# ----> 1 aspiradora = Agente()
#       2 tablero = Tablero(n_celdas=(5, 5))
#       3
#       4 basura1 = Agente(2, 2, 0, emoticon="🍂", tamano_emoticon=30)
#       5 basura2 = Agente(3, 3, 0, emoticon="🍂", tamano_emoticon=30)
#
# TypeError: Agente.__init__() missing 1 required positional argument: 'tablero'

# %%
# Solución propuesta
import random
import matplotlib.pyplot as plt
from IPython.display import display
import ipywidgets as widgets
import time

class Tablero:
    def __init__(self, tamano=5, hojas=10):
        self.tamano = tamano
        self.hojas = set()
        while len(self.hojas) < hojas:
            self.hojas.add((random.randint(0, tamano - 1), random.randint(0, tamano - 1)))
        self.out = widgets.HTML()
        display(self.out)

    def dibujar(self, agente):
        tablero = "<table border='1'>"
        for i in range(self.tamano):
            tablero += "<tr>"
            for j in range(self.tamano):
                contenido = ""
                if (j, i) in self.hojas:
                    contenido = "🍂"
                if agente.x == j and agente.y == i:
                    contenido = agente.emoticon
                tablero += f"<td style='width:50px;height:50px;text-align:center;font-size:30px;'>{contenido}</td>"
            tablero += "</tr>"
        tablero += "</table>"
        self.out.value = tablero

    def limpiar(self, x, y):
        if (x, y) in self.hojas:
            self.hojas.remove((x, y))
            return True
        return False

# %%
##Haz un agente aspiradora con los siguientes requisitos

## * El agente aspiradora puede percibir las hojas en cualquiera de las 4 casillas adyacentes (N, S, W, E).
##* El agente puede percibir los muros del tablero
##  * El agente aspiradora dispondrá de 6 acciones:  moverse a cualquiera de las 4 casillas adyacentes (N, S, W, E), aspirar o no realizar ninguna acción.
##  * El agente obtendrá un punto por cada cuadrado que se limpie.
##  * La posición inicial de la aspiradora deberá generarse de manera aleatoria en el tablero.
##  * La aspiradora solo tiene energía para realizar 100 movimientos. Las acciones de aspirar y percibir las hojas no consumen energía.
##  * El tablero debe tener un tamaño de 5 x 5.
##  * Se deben ubicar 10 hojas de manera aleatoria en el tablero.
class Agente:
    def __init__(self, tablero):
        self.x = random.randint(0, tablero.tamano - 1)
        self.y = random.randint(0, tablero.tamano - 1)
        self.emoticon = "🤖"
        self.energia = 100
        self.puntaje = 0
        self.tablero = tablero

    def percibir(self):
        percepcion = {
            'N': (self.x, self.y - 1) in self.tablero.hojas if self.y > 0 else None,
            'S': (self.x, self.y + 1) in self.tablero.hojas if self.y < self.tablero.tamano - 1 else None,
            'W': (self.x - 1, self.y) in self.tablero.hojas if self.x > 0 else None,
            'E': (self.x + 1, self.y) in self.tablero.hojas if self.x < self.tablero.tamano - 1 else None,
        }
        return percepcion

    def mover(self, direccion):
        if self.energia > 0:
            if direccion == 'N' and self.y > 0:
                self.y -= 1
            elif direccion == 'S' and self.y < self.tablero.tamano - 1:
                self.y += 1
            elif direccion == 'W' and self.x > 0:
                self.x -= 1
            elif direccion == 'E' and self.x < self.tablero.tamano - 1:
                self.x += 1
            self.energia -= 1

    def aspirar(self):
        if self.tablero.limpiar(self.x, self.y):
            self.puntaje += 1

    def actuar(self):
        while self.energia > 0:
            percepcion = self.percibir()
            if self.tablero.limpiar(self.x, self.y):
                self.puntaje += 1
            elif True in percepcion.values():
                for dir, hoja in percepcion.items():
                    if hoja:
                        self.mover(dir)
                        break
            else:
                self.mover(random.choice(['N', 'S', 'W', 'E']))
            self.tablero.dibujar(self)
            time.sleep(0.1)

# %%
# Ejecutar simulaciones
resultados = []
for _ in range(50):
    tablero = Tablero()
    agente = Agente(tablero)
    agente.actuar()
    resultados.append(agente.puntaje)

# Graficar histograma
plt.hist(resultados, bins=20, edgecolor='black')
plt.xlabel("Puntaje obtenido")
plt.ylabel("Frecuencia")
plt.title("Distribución del puntaje en 50 simulaciones")
plt.show()
# Out:
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')

# %% [markdown]
# Según los resultados obtenido el agente reflejo dio unos resultados óptimos.
# Aunque la estrategia planteada no guardaba las celdas por las que el agente ya había pasado para poder optimizar las rutas, y la aproximación que tenía el agente no era muy alta por lo que si las celdas cerca ya estaban limpias, generaba movimientos aleatorios, malgastando el combustible que tenía, de todas maneras dió unos buenos resultados.

# %% [markdown]
# #### __5. (1.5 puntos) IImplemente una simulación para el problema del robot aspiradora presentado en clase. La simulación debe cumplir las siguientes especificaciones:__
#
#   * El agente aspiradora puede percibir las hojas en cualquiera de las 8 casillas adyacentes (se incluyen las diagonales).
#   * El agente puede percibir los muros del tablero
#   * El agente aspiradora dispondrá de 10 acciones:  moverse a cualquiera de las 8 casillas adyacentes aspirar o no realizar ningúna acción.
#   * El agente obtendrá un punto por cada cuadrado que se límpie.
#   * La posición inicial de la aspiradora deberá generarse de manera aleatoria en el tablero.
#   * La aspiradora solo tiene energía para realizar 200 acciones. La acciones de aspirar y percipir las hojas no consumen energía.
#   * El tablero debe tener un tamaño de 10 x 10.
#   * Se deben ubicar 50 hojas de manera aleatoria en el tablero.
#
# __Utilizando los parámetros mencionados:__
#
#   * Genere un comportamiento basado en estado que maximice el puntaje obtenido por la aspiradora. Describa la estrategia utilizada.
#   * Realice 50 simulaciones con el comportamiento diseñado y realice un histograma con los puntajes obtenidos.
#   * ¿Es posible construir un agente racional que soluciones este problema mediante un comportamiento basado en estado?

# %%
# Solución propuesta

import random
import matplotlib.pyplot as plt
from IPython.display import display
import ipywidgets as widgets
import time

class Tablero:
    def __init__(self, tamano=10, hojas=50):
        self.tamano = tamano
        self.hojas = set()
        while len(self.hojas) < hojas:
            self.hojas.add((random.randint(0, tamano - 1), random.randint(0, tamano - 1)))
        self.out = widgets.HTML()
        display(self.out)

    def dibujar(self, agente):
        tablero = "<table border='1'>"
        for i in range(self.tamano):
            tablero += "<tr>"
            for j in range(self.tamano):
                contenido = ""
                if (j, i) in self.hojas:
                    contenido = "🍂"
                if agente.x == j and agente.y == i:
                    contenido = agente.emoticon
                tablero += f"<td style='width:50px;height:50px;text-align:center;font-size:30px;'>{contenido}</td>"
            tablero += "</tr>"
        tablero += "</table>"
        self.out.value = tablero

    def limpiar(self, x, y):
        if (x, y) in self.hojas:
            self.hojas.remove((x, y))
            return True
        return False
##prompt usado: Haz un agente aspiradora con los siguientes requisitos.
##   * El agente aspiradora puede percibir las hojas en cualquiera de las 8 casillas adyacentes (se incluyen las diagonales).
##   * El agente aspiradora puede percibir las hojas en cualquiera de las 8 casillas adyacentes (se incluyen las diagonales).
## * El agente puede percibir los muros del tablero
##  * El agente aspiradora dispondrá de 10 acciones:  moverse a cualquiera de las 8 casillas adyacentes aspirar o no realizar ningúna acción.
##  * El agente obtendrá un punto por cada cuadrado que se límpie.
##  * La posición inicial de la aspiradora deberá generarse de manera aleatoria en el tablero.
##  * La aspiradora solo tiene energía para realizar 200 acciones. La acciones de aspirar y percipir las hojas no consumen energía.
##  * El tablero debe tener un tamaño de 10 x 10.
##  * Se deben ubicar 50 hojas de manera aleatoria en el tablero

class Agente:
    def __init__(self, tablero):
        self.x = random.randint(0, tablero.tamano - 1)
        self.y = random.randint(0, tablero.tamano - 1)
        self.emoticon = "🤖"
        self.energia = 200
        self.puntaje = 0
        self.tablero = tablero
        self.visitados = set()

    def percibir(self):
        percepcion = {}
        for dx in [-1, 0, 1]:
            for dy in [-1, 0, 1]:
                if dx == 0 and dy == 0:
                    continue
                nx, ny = self.x + dx, self.y + dy
                if 0 <= nx < self.tablero.tamano and 0 <= ny < self.tablero.tamano:
                    percepcion[(nx, ny)] = (nx, ny) in self.tablero.hojas
        return percepcion

    def mover(self, direccion):
        if self.energia > 0:
            nx, ny = self.x + direccion[0], self.y + direccion[1]
            if 0 <= nx < self.tablero.tamano and 0 <= ny < self.tablero.tamano:
                self.x, self.y = nx, ny
                self.energia -= 1

    def aspirar(self):
        if self.tablero.limpiar(self.x, self.y):
            self.puntaje += 1

    def actuar(self):
        while self.energia > 0:
            self.aspirar()
            percepcion = self.percibir()
            hojas_cercanas = [pos for pos, tiene_hoja in percepcion.items() if tiene_hoja]
            if hojas_cercanas:
                destino = random.choice(hojas_cercanas)
                self.mover((destino[0] - self.x, destino[1] - self.y))
            else:
                movimientos_posibles = [(dx, dy) for dx in [-1, 0, 1] for dy in [-1, 0, 1] if (dx, dy) != (0, 0)]
                destino = random.choice(movimientos_posibles)
                self.mover(destino)
            self.tablero.dibujar(self)
            time.sleep(0.1)

# Ejecutar simulaciones
resultados = []
for _ in range(50):
    tablero = Tablero()
    agente = Agente(tablero)
    agente.actuar()
    resultados.append(agente.puntaje)

# Graficar histograma
plt.hist(resultados, bins=10, edgecolor='black')
plt.xlabel("Puntaje obtenido")
plt.ylabel("Frecuencia")
plt.title("Distribución del puntaje en 50 simulaciones")
plt.show()
# Out:
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')
# HTML(value='')

# %% [markdown]
# Aunque se supone que el agente basado en estado debería dar mejores resultados, su distribución nos muestra que varias veces dejaba muchas casillas sin limpiar,aunque en la mayor parte de sus intentos se limpiaban todas las casillas.
# La estrategia usada con este agente se basa en que el agente tiene una memoria en donde sabe en cuales casillas ya limpió, para poder ahorrar movimimentos, pero no fue del todo optima.
